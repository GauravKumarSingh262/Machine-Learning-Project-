# %% [markdown]
# # Milestone 3

# %% [markdown]
# # Heart Disease Dataset With Hyperparameter Tunning using GridSearchCV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('C:/Users/DELL/Downloads/heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
# Categorical columns (10 or fewer unique values)
categorical_cols = df.columns[df.nunique() <= 10].tolist()

# Numerical columns (more than 10 unique values)
numerical_cols = df.columns[df.nunique() > 10].tolist()

print("Categorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']
# Numerical columns: ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %% [raw]
# # This suggests
#
# Categorical Columns:
#
# 1. Sex (2 unique values)
# 2. CP (4 unique values)
# 3. Fbs (2 unique values)
# 4. Restecg (3 unique values)
# 5. Exang (2 unique values)
# 6. Slope (3 unique values)
# 7. Ca (5 unique values)
# 8. Thal (4 unique values)
# 9. Target (2 unique values)
#
#
# Numerical Columns:
#
# 1. Age
# 2. Trestbps
# 3. Chol
# 4. Thalach
# 5. Oldpeak

# %%
# Outlier detection and removal
for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    # Detecting outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    
    # Print outlier count
    print(f"Outliers in {col}: {outliers.shape[0]}")
    
    # Remove outliers
    df = df[~((df[col] < lower_bound) | (df[col] > upper_bound))]
    
    # Visualizing outliers using boxplot
    plt.figure(figsize=(8, 6))
    sns.boxplot(df[col])
    plt.title(f"Boxplot of {col} after outlier removal")
    plt.show()
# Out:
# Outliers in age: 0
# Outliers in trestbps: 30
# Outliers in chol: 16
# Outliers in thalach: 4
# Outliers in oldpeak: 11

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.shape
# Out:
# (964, 14)

# %%
plt.hist(df['age'],bins=10,color='green')
# Out:
# (array([  4.,  39., 109., 125., 117., 187., 203., 128.,  43.,   9.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['trestbps'],bins=10,color='green')
# Out:
# (array([ 24.,  42., 100., 190., 213., 118., 137.,  79.,  39.,  22.]),
#  array([ 94. , 101.6, 109.2, 116.8, 124.4, 132. , 139.6, 147.2, 154.8,
#         162.4, 170. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['chol'],bins=10,color='green')
# Out:
# (array([ 17.,  25.,  89., 185., 194., 176., 123.,  91.,  43.,  21.]),
#  array([126. , 149.4, 172.8, 196.2, 219.6, 243. , 266.4, 289.8, 313.2,
#         336.6, 360. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['thalach'],bins=10,color='green')
# Out:
# (array([ 24.,  36.,  73., 118., 124., 167., 179., 180.,  53.,  10.]),
#  array([ 88. ,  99.4, 110.8, 122.2, 133.6, 145. , 156.4, 167.8, 179.2,
#         190.6, 202. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['oldpeak'],bins=10,color='green')
# Out:
# (array([420., 103., 114.,  94.,  81.,  42.,  46.,  29.,  24.,  11.]),
#  array([0.  , 0.42, 0.84, 1.26, 1.68, 2.1 , 2.52, 2.94, 3.36, 3.78, 4.2 ]),
#  <BarContainer object of 10 artists>)

# %%
df.groupby(['target']).count()
# Out:
#         age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# target
# 0       456  456  456       456   456  456      456      456    456      456
# 1       508  508  508       508   508  508      508      508    508      508
#
#         slope   ca  thal
# target
# 0         456  456   456
# 1         508  508   508

# %%
a=df.groupby(['target']).size().reset_index(name='count').rename(columns={'target':'DiseasePresence'}) # O for healthy and 1 for diseased
a
# Out:
#    DiseasePresence  count
# 0                0    456
# 1                1    508

# %%
plt.figure(figsize=(20,10))
plt.bar(a['DiseasePresence'], a['count'])
plt.xlabel('Disease Presence')  # x-axis label
plt.ylabel('Count')  # y-axis label
plt.title('Disease Presence Distribution')  # optional title
plt.show()

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
sns.pairplot(df,hue='target')

# %%
x=df.iloc[:,:-1]
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
x.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.073993 -0.064323  0.269362  0.187829  0.109329
# sex      -0.073993  1.000000 -0.081931 -0.002355 -0.123396  0.051455
# cp       -0.064323 -0.081931  1.000000  0.076465 -0.089317  0.071809
# trestbps  0.269362 -0.002355  0.076465  1.000000  0.113626  0.123920
# chol      0.187829 -0.123396 -0.089317  0.113626  1.000000  0.031780
# fbs       0.109329  0.051455  0.071809  0.123920  0.031780  1.000000
# restecg  -0.138529 -0.074475  0.082116 -0.151314 -0.146065 -0.100853
# thalach  -0.402295 -0.047625  0.301058 -0.060029 -0.042601 -0.025174
# exang     0.087455  0.183040 -0.400875 -0.009736  0.087461  0.027136
# oldpeak   0.205841  0.149620 -0.156566  0.133319  0.013200  0.016365
# slope    -0.153800 -0.055996  0.109582 -0.077201  0.020391 -0.067493
# ca        0.280354  0.153932 -0.157566  0.113774  0.066656  0.139401
# thal      0.063173  0.235266 -0.183412 -0.012197  0.103657 -0.078023
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(x.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.lmplot(x='thalach', y='oldpeak', hue='target', data=df)
plt.show()

# %%
x=df.drop(columns=['target'])
y=df['target']
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 964, dtype: int64

# %%
from sklearn.feature_selection import f_classif
a=f_classif(x,y)
a
# Out:
# (array([ 52.55650761, 108.13170468, 205.80610771,  11.77302565,
#          15.78805862,   1.52622117,  29.0802467 , 213.91321996,
#         228.44290963, 239.65858734, 116.19439063, 156.88734103,
#         132.67843121]),
#  array([8.58053462e-13, 4.48707752e-24, 1.93641102e-42, 6.26516229e-04,
#         7.61409501e-05, 2.16982079e-01, 8.74096898e-08, 6.83925686e-44,
#         1.81223443e-46, 1.95455095e-48, 1.17560747e-25, 1.88403640e-33,
#         7.51015932e-29]))

# %%
a=pd.Series(a[1])
a.index=x.columns
a
# Out:
# age         8.580535e-13
# sex         4.487078e-24
# cp          1.936411e-42
# trestbps    6.265162e-04
# chol        7.614095e-05
# fbs         2.169821e-01
# restecg     8.740969e-08
# thalach     6.839257e-44
# exang       1.812234e-46
# oldpeak     1.954551e-48
# slope       1.175607e-25
# ca          1.884036e-33
# thal        7.510159e-29
# dtype: float64

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
x=df.drop(columns=['target'])
y=df['target']
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 964, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
rf=RandomForestClassifier()
param_grid = {
    'n_estimators': [7,10,15],
    'max_depth': [15,20,25],
    'min_samples_split': [5,7,8]
}

# %%
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=5,scoring='accuracy')

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [15, 20, 25],
#                          'min_samples_split': [5, 7, 8],
#                          'n_estimators': [7, 10, 15]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 10}

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=15, min_samples_split=5, n_estimators=10)

# %%
p=grid_search.best_estimator_.predict(x_test)
print(f"The accuracy of our model is: {accuracy_score(pr,y_test)}")
# Out:
# The accuracy of our model is: 0.9623824451410659

# %%
print(classification_report(p,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       158
#            1       0.97      0.96      0.96       161
#
#     accuracy                           0.96       319
#    macro avg       0.96      0.96      0.96       319
# weighted avg       0.96      0.96      0.96       319

# %%
import joblib
joblib.dump(grid_search,'E:/Milestone/Heart_RandomForestClassifier.pkl')
# Out:
# ['E:/Milestone/Heart_RandomForestClassifier.pkl']

# %%
# for training set
pre=grid_search.best_estimator_.predict(x_train)
print(f"The accuracy of our model is: {accuracy_score(pre,y_train)}")
# Out:
# The accuracy of our model is: 0.9953488372093023

# %%
print(classification_report(pre,y_train)) # for training set
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       295
#            1       1.00      0.99      1.00       350
#
#     accuracy                           1.00       645
#    macro avg       1.00      1.00      1.00       645
# weighted avg       1.00      1.00      1.00       645
